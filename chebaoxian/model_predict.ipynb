# %%
import numpy as np
import pandas as pd
import gc
from sklearn.model_selection import train_test_split

# %%
df_final=pd.read_csv('/home/mw/work/df_final.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ba8bd6dae281> in <module>
# ----> 1 df_final=pd.read_csv('/home/mw/work/df_final.csv')
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
# ...

# %%
print(df_final.shape)

# %%
# 分开train和test
# df_train = df_final[df_final['train'] == 1]
# df_train = df_train.drop(['train',],axis=1)

# df_test = df_final[df_final['train'] == 0]
# test_ids=df_test['carid']
# df_test = df_test.drop(['train','y1_is_purchase','carid'],axis=1)

# target= df_train['y1_is_purchase']
# df_train = df_train.drop(['y1_is_purchase','carid'],axis=1)

# %%
result=pd.read_csv('/home/mw/work/result.csv')
print(result.head(10))
# Out:
#                                           carid  label
# 0  ZhCSxFMK2Pv4mkVwSNQeF0HwKQpm78mD4OA4t/gX79k=    0.0
# 1  MN3k6VEj1c1yflYHmZbnChWcB4YFunAJxn2a/oNibMo=    0.0
# 2  q0hlS2GQL/TvAvJ4QaNYOmnostsrxOd47UguA9jfsL0=    1.0
# 3  vq73YiH8neXWAG6GLRqKNmtbcMt6VexhGjdGHpqdVTg=    0.0
# 4  IAJ37++ziuqd5wAgRKP5maZjY0hmgqo5D5Wi1CENlsM=    1.0
# 5  kFTqMxyBpYAfay63NYSWKEy9vW7uW6C5C7li8Iflen8=    0.0
# 6  SjxFhX4ysOC8AzJpmVDAPhpRmWpwp//5S8vIY2B/NBs=    1.0
# 7  FLrxaBb6uiVEwu0UVXP9oDgMd4rpgJND496zKMwZtPo=    1.0
# 8  R6KwzjQhYyXVjSpjslAznQ+ATk6XXzgm2TdS25mM42s=    1.0
# 9  BOJvNrQXjP+7fax/TBStUTqrj8bTtwbVAuwNLfFOcFE=    1.0
